# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

from transaction_analysis.config.paths import FRAUD_DATASET_DIR
from transaction_analysis.data.step.preprocess import try_downcast

mcc_codes = (
    pd.read_json(FRAUD_DATASET_DIR / "raw" / "mcc_codes.json", typ="series")
    .rename_axis("id")
    .rename("description")
    .reset_index()
    .pipe(try_downcast, "id", "unsigned")
)

mcc_codes.info()
